# %%
# Import the dependencies.
import pandas as pd
# Import the datetime module from the datetime library.
from datetime import datetime 
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Import the API key.
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5b1fbfefa54b42c4bc203708830675e5

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 589

# %%
#need help
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    #print(city_url)
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description=city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        try:
            city_rain=city_weather["rain"]["3h"]
        except:
            city_rain=0
            #Snow info
        try:
            city_snow=city_weather["snow"]["3h"]
        except:
            city_snow=0
    
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description":city_description,
                          "Rain":city_rain,
                          "Snow":city_snow,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chuy
# Processing Record 2 of Set 1 | arraial do cabo
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | geraldton
# Processing Record 5 of Set 1 | tiznit
# Processing Record 6 of Set 1 | sitka
# Processing Record 7 of Set 1 | aranda de duero
# Processing Record 8 of Set 1 | buchanan
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | piacabucu
# Processing Record 12 of Set 1 | portland
# Processing Record 13 of Set 1 | koungou
# City not found. Skipping...
# Processing Record 14 of Set 1 | meadow lake
# Processing Record 15 of Set 1 | kokopo
# Processing Record 16 of Set 1 | narsaq
# Processing Record 17 of Set 1 | jimeta
# Processing Record 18 of Set 1 | salalah
# Processing Record 19 of Set 1 | cayenne
# Processing Record 20 of Set 1 | castro
# Processing Record 21 of Set 1 | belmonte
# Processing Record 22 of Set 1 | georgetown
# Processing Record 23 of Set 1 | svetlogorsk
# Processing Record 24 of Set 1 | mocuba
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | fortuna
# Processing Record 27 of Set 1 | muswellbrook
# Processing Record 28 of Set 1 | khatanga
# Processing Record 29 of Set 1 | verkhoyansk
# Processing Record 30 of Set 1 | dingle
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | mahebourg
# Processing Record 33 of Set 1 | cherskiy
# Processing Record 34 of Set 1 | bethel
# Processing Record 35 of Set 1 | auki
# Processing Record 36 of Set 1 | ginda
# Processing Record 37 of Set 1 | mandurah
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | berlevag
# Processing Record 41 of Set 1 | lorengau
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | bluff
# Processing Record 44 of Set 1 | hamilton
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | severo-kurilsk
# Processing Record 47 of Set 1 | whitehorse
# Processing Record 48 of Set 1 | talnakh
# Processing Record 49 of Set 1 | dinguiraye
# Processing Record 50 of Set 1 | ribeira grande
# Processing Record 1 of Set 2 | banjar
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | mar del plata
# Processing Record 4 of Set 2 | ilulissat
# Processing Record 5 of Set 2 | srednekolymsk
# Processing Record 6 of Set 2 | butaritari
# Processing Record 7 of Set 2 | batsfjord
# Processing Record 8 of Set 2 | gardan diwal
# City not found. Skipping...
# Processing Record 9 of Set 2 | tiksi
# Processing Record 10 of Set 2 | nikolskoye
# Processing Record 11 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 2 | ormara
# Processing Record 13 of Set 2 | vila velha
# Processing Record 14 of Set 2 | goure
# Processing Record 15 of Set 2 | saskylakh
# Processing Record 16 of Set 2 | pimentel
# Processing Record 17 of Set 2 | kavieng
# Processing Record 18 of Set 2 | punta arenas
# Processing Record 19 of Set 2 | dikson
# Processing Record 20 of Set 2 | katsuura
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | olafsvik
# City not found. Skipping...
# Processing Record 23 of Set 2 | jamestown
# Processing Record 24 of Set 2 | necochea
# Processing Record 25 of Set 2 | gizo
# Processing Record 26 of Set 2 | busselton
# Processing Record 27 of Set 2 | saurimo
# Processing Record 28 of Set 2 | ahipara
# Processing Record 29 of Set 2 | inhambane
# Processing Record 30 of Set 2 | sur
# Processing Record 31 of Set 2 | port elizabeth
# Processing Record 32 of Set 2 | damavand
# Processing Record 33 of Set 2 | hillsboro
# Processing Record 34 of Set 2 | college
# Processing Record 35 of Set 2 | esperance
# Processing Record 36 of Set 2 | wundanyi
# Processing Record 37 of Set 2 | hobart
# Processing Record 38 of Set 2 | saldanha
# Processing Record 39 of Set 2 | mikhaylov
# Processing Record 40 of Set 2 | samana
# Processing Record 41 of Set 2 | pimenta bueno
# Processing Record 42 of Set 2 | provideniya
# Processing Record 43 of Set 2 | birjand
# Processing Record 44 of Set 2 | dunedin
# Processing Record 45 of Set 2 | bubaque
# Processing Record 46 of Set 2 | puerto maldonado
# Processing Record 47 of Set 2 | kahului
# Processing Record 48 of Set 2 | ukwa
# Processing Record 49 of Set 2 | flin flon
# Processing Record 50 of Set 2 | carnarvon
# Processing Record 1 of Set 3 | portales
# Processing Record 2 of Set 3 | nizwa
# Processing Record 3 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 4 of Set 3 | qaanaaq
# Processing Record 5 of Set 3 | mlonggo
# Processing Record 6 of Set 3 | hermanus
# Processing Record 7 of Set 3 | chongoyape
# Processing Record 8 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 3 | kavaratti
# Processing Record 10 of Set 3 | chokurdakh
# Processing Record 11 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 3 | borogontsy
# Processing Record 13 of Set 3 | kaitangata
# Processing Record 14 of Set 3 | tuktoyaktuk
# Processing Record 15 of Set 3 | manoel urbano
# Processing Record 16 of Set 3 | bria
# Processing Record 17 of Set 3 | bonthe
# Processing Record 18 of Set 3 | upernavik
# Processing Record 19 of Set 3 | san quintin
# Processing Record 20 of Set 3 | kannangad
# Processing Record 21 of Set 3 | te anau
# Processing Record 22 of Set 3 | salym
# Processing Record 23 of Set 3 | new norfolk
# Processing Record 24 of Set 3 | pevek
# Processing Record 25 of Set 3 | vardo
# Processing Record 26 of Set 3 | bredasdorp
# Processing Record 27 of Set 3 | gamba
# Processing Record 28 of Set 3 | ust-nera
# Processing Record 29 of Set 3 | east london
# Processing Record 30 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 3 | puerto ayora
# Processing Record 33 of Set 3 | agadez
# Processing Record 34 of Set 3 | youghal
# Processing Record 35 of Set 3 | lagoa
# Processing Record 36 of Set 3 | saint-pierre
# Processing Record 37 of Set 3 | sibolga
# Processing Record 38 of Set 3 | peniche
# Processing Record 39 of Set 3 | sokolov
# Processing Record 40 of Set 3 | saint-philippe
# Processing Record 41 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 3 | boda
# Processing Record 43 of Set 3 | villablino
# Processing Record 44 of Set 3 | terre-de-bas
# Processing Record 45 of Set 3 | deputatskiy
# Processing Record 46 of Set 3 | mount gambier
# Processing Record 47 of Set 3 | aklavik
# Processing Record 48 of Set 3 | quelimane
# Processing Record 49 of Set 3 | vaini
# Processing Record 50 of Set 3 | iskateley
# Processing Record 1 of Set 4 | kraslava
# Processing Record 2 of Set 4 | faya
# Processing Record 3 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 4 | sola
# Processing Record 5 of Set 4 | gat
# Processing Record 6 of Set 4 | tilichiki
# Processing Record 7 of Set 4 | kodiak
# Processing Record 8 of Set 4 | kungurtug
# Processing Record 9 of Set 4 | doha
# Processing Record 10 of Set 4 | half moon bay
# Processing Record 11 of Set 4 | kenora
# Processing Record 12 of Set 4 | gambela
# Processing Record 13 of Set 4 | victoria
# Processing Record 14 of Set 4 | pisco
# Processing Record 15 of Set 4 | souillac
# Processing Record 16 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 4 | bambous virieux
# Processing Record 18 of Set 4 | santa lucia
# Processing Record 19 of Set 4 | barrow
# Processing Record 20 of Set 4 | airai
# Processing Record 21 of Set 4 | avera
# Processing Record 22 of Set 4 | bathurst
# Processing Record 23 of Set 4 | naze
# Processing Record 24 of Set 4 | guerrero negro
# Processing Record 25 of Set 4 | longyearbyen
# Processing Record 26 of Set 4 | lompoc
# Processing Record 27 of Set 4 | donegal
# Processing Record 28 of Set 4 | ostrovnoy
# Processing Record 29 of Set 4 | cabra
# Processing Record 30 of Set 4 | williston
# Processing Record 31 of Set 4 | manta
# Processing Record 32 of Set 4 | fort-shevchenko
# Processing Record 33 of Set 4 | tha chang
# Processing Record 34 of Set 4 | lahaina
# Processing Record 35 of Set 4 | baijiantan
# Processing Record 36 of Set 4 | champerico
# Processing Record 37 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 4 | kijang
# Processing Record 39 of Set 4 | tsogni
# Processing Record 40 of Set 4 | henties bay
# Processing Record 41 of Set 4 | saint george
# Processing Record 42 of Set 4 | port hardy
# Processing Record 43 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 4 | nata
# Processing Record 45 of Set 4 | antalaha
# Processing Record 46 of Set 4 | hofn
# Processing Record 47 of Set 4 | ust-uda
# Processing Record 48 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 49 of Set 4 | luderitz
# Processing Record 50 of Set 4 | paamiut
# Processing Record 1 of Set 5 | poitiers
# Processing Record 2 of Set 5 | straumen
# Processing Record 3 of Set 5 | hasaki
# Processing Record 4 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 5 | vangaindrano
# Processing Record 6 of Set 5 | cascais
# Processing Record 7 of Set 5 | seoul
# Processing Record 8 of Set 5 | bengkulu
# City not found. Skipping...
# Processing Record 9 of Set 5 | kingaroy
# Processing Record 10 of Set 5 | cedar city
# Processing Record 11 of Set 5 | dabat
# Processing Record 12 of Set 5 | setaka
# Processing Record 13 of Set 5 | muroto
# Processing Record 14 of Set 5 | bilma
# Processing Record 15 of Set 5 | faanui
# Processing Record 16 of Set 5 | norman wells
# Processing Record 17 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 5 | karakendzha
# City not found. Skipping...
# Processing Record 19 of Set 5 | coihaique
# Processing Record 20 of Set 5 | nicoya
# Processing Record 21 of Set 5 | celestun
# Processing Record 22 of Set 5 | tasiilaq
# Processing Record 23 of Set 5 | novoyegoryevskoye
# City not found. Skipping...
# Processing Record 24 of Set 5 | gisborne
# Processing Record 25 of Set 5 | abha
# Processing Record 26 of Set 5 | kruisfontein
# Processing Record 27 of Set 5 | mandan
# Processing Record 28 of Set 5 | khuzhir
# Processing Record 29 of Set 5 | pangnirtung
# Processing Record 30 of Set 5 | kyzyl-suu
# Processing Record 31 of Set 5 | cabo san lucas
# Processing Record 32 of Set 5 | hithadhoo
# Processing Record 33 of Set 5 | yulara
# Processing Record 34 of Set 5 | gorontalo
# Processing Record 35 of Set 5 | ambilobe
# Processing Record 36 of Set 5 | galesong
# Processing Record 37 of Set 5 | araouane
# Processing Record 38 of Set 5 | almaznyy
# Processing Record 39 of Set 5 | ayna
# Processing Record 40 of Set 5 | manzhouli
# Processing Record 41 of Set 5 | lubango
# Processing Record 42 of Set 5 | lebu
# Processing Record 43 of Set 5 | fort morgan
# Processing Record 44 of Set 5 | popondetta
# Processing Record 45 of Set 5 | rawson
# Processing Record 46 of Set 5 | charyshskoye
# Processing Record 47 of Set 5 | pedasi
# Processing Record 48 of Set 5 | leningradskiy
# Processing Record 49 of Set 5 | stokmarknes
# Processing Record 50 of Set 5 | vila
# Processing Record 1 of Set 6 | bathsheba
# Processing Record 2 of Set 6 | teguise
# Processing Record 3 of Set 6 | grande-synthe
# Processing Record 4 of Set 6 | livenka
# Processing Record 5 of Set 6 | boquete
# Processing Record 6 of Set 6 | hualmay
# Processing Record 7 of Set 6 | kwinana
# Processing Record 8 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 6 | grindavik
# Processing Record 10 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 6 | bairiki
# City not found. Skipping...
# Processing Record 12 of Set 6 | martapura
# Processing Record 13 of Set 6 | iqaluit
# Processing Record 14 of Set 6 | waseca
# Processing Record 15 of Set 6 | kenai
# Processing Record 16 of Set 6 | uribia
# Processing Record 17 of Set 6 | emerald
# Processing Record 18 of Set 6 | ola
# Processing Record 19 of Set 6 | botshabelo
# Processing Record 20 of Set 6 | mangrol
# Processing Record 21 of Set 6 | puerto escondido
# Processing Record 22 of Set 6 | ayagoz
# Processing Record 23 of Set 6 | parfenyevo
# Processing Record 24 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 6 | conchas
# Processing Record 26 of Set 6 | san patricio
# Processing Record 27 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 28 of Set 6 | kars
# Processing Record 29 of Set 6 | nanortalik
# Processing Record 30 of Set 6 | ucluelet
# Processing Record 31 of Set 6 | khuzdar
# Processing Record 32 of Set 6 | turtas
# Processing Record 33 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 6 | muriti
# Processing Record 35 of Set 6 | casian
# Processing Record 36 of Set 6 | goba
# Processing Record 37 of Set 6 | coquimbo
# Processing Record 38 of Set 6 | leh
# Processing Record 39 of Set 6 | northam
# Processing Record 40 of Set 6 | oranjemund
# Processing Record 41 of Set 6 | arkhangelsk
# Processing Record 42 of Set 6 | yellowknife
# Processing Record 43 of Set 6 | menongue
# Processing Record 44 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 45 of Set 6 | luanda
# Processing Record 46 of Set 6 | tigil
# Processing Record 47 of Set 6 | rundu
# Processing Record 48 of Set 6 | sangar
# Processing Record 49 of Set 6 | muisne
# Processing Record 50 of Set 6 | sao filipe
# Processing Record 1 of Set 7 | trinidad
# Processing Record 2 of Set 7 | wanning
# Processing Record 3 of Set 7 | butembo
# Processing Record 4 of Set 7 | taboga
# Processing Record 5 of Set 7 | banganapalle
# Processing Record 6 of Set 7 | qaqortoq
# Processing Record 7 of Set 7 | maceio
# Processing Record 8 of Set 7 | plouzane
# Processing Record 9 of Set 7 | hervey bay
# Processing Record 10 of Set 7 | puerto carreno
# Processing Record 11 of Set 7 | mount pleasant
# Processing Record 12 of Set 7 | jacareacanga
# Processing Record 13 of Set 7 | itupiranga
# Processing Record 14 of Set 7 | sambava
# Processing Record 15 of Set 7 | tongzi
# Processing Record 16 of Set 7 | jardim
# Processing Record 17 of Set 7 | honningsvag
# Processing Record 18 of Set 7 | kouango
# Processing Record 19 of Set 7 | kirkuk
# Processing Record 20 of Set 7 | nusaybin
# Processing Record 21 of Set 7 | hay river
# Processing Record 22 of Set 7 | dumka
# Processing Record 23 of Set 7 | ponta do sol
# Processing Record 24 of Set 7 | santa clara
# Processing Record 25 of Set 7 | bosaso
# Processing Record 26 of Set 7 | sedelnikovo
# City not found. Skipping...
# Processing Record 27 of Set 7 | klaksvik
# Processing Record 28 of Set 7 | mabaruma
# Processing Record 29 of Set 7 | maniitsoq
# Processing Record 30 of Set 7 | channel-port aux basques
# Processing Record 31 of Set 7 | odweyne
# City not found. Skipping...
# Processing Record 32 of Set 7 | barra do garcas
# Processing Record 33 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 34 of Set 7 | constitucion
# Processing Record 35 of Set 7 | kpandae
# Processing Record 36 of Set 7 | yar-sale
# Processing Record 37 of Set 7 | lubumbashi
# Processing Record 38 of Set 7 | sao felix do xingu
# Processing Record 39 of Set 7 | sinnamary
# Processing Record 40 of Set 7 | songea
# Processing Record 41 of Set 7 | westport
# Processing Record 42 of Set 7 | fairbanks
# Processing Record 43 of Set 7 | carauari
# Processing Record 44 of Set 7 | mbour
# Processing Record 45 of Set 7 | laguna
# Processing Record 46 of Set 7 | neuquen
# Processing Record 47 of Set 7 | mutis
# Processing Record 48 of Set 7 | asfi
# City not found. Skipping...
# Processing Record 49 of Set 7 | beian
# Processing Record 50 of Set 7 | port blair
# Processing Record 1 of Set 8 | najran
# Processing Record 2 of Set 8 | kalachinsk
# Processing Record 3 of Set 8 | maumere
# Processing Record 4 of Set 8 | bowen
# Processing Record 5 of Set 8 | selma
# Processing Record 6 of Set 8 | ancud
# Processing Record 7 of Set 8 | nabire
# Processing Record 8 of Set 8 | casa grande
# Processing Record 9 of Set 8 | kota kinabalu
# Processing Record 10 of Set 8 | xuzhou
# Processing Record 11 of Set 8 | tabou
# Processing Record 12 of Set 8 | taitung
# Processing Record 13 of Set 8 | tuatapere
# Processing Record 14 of Set 8 | merauke
# Processing Record 15 of Set 8 | ailigandi
# Processing Record 16 of Set 8 | puerto del rosario
# Processing Record 17 of Set 8 | awjilah
# Processing Record 18 of Set 8 | wakkanai
# Processing Record 19 of Set 8 | muika
# City not found. Skipping...
# Processing Record 20 of Set 8 | acapulco
# Processing Record 21 of Set 8 | cidreira
# Processing Record 22 of Set 8 | camacha
# Processing Record 23 of Set 8 | evensk
# Processing Record 24 of Set 8 | ketchikan
# Processing Record 25 of Set 8 | namibe
# Processing Record 26 of Set 8 | olinda
# Processing Record 27 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 28 of Set 8 | casper
# Processing Record 29 of Set 8 | cabadiangan
# Processing Record 30 of Set 8 | alice springs
# Processing Record 31 of Set 8 | tomatlan
# Processing Record 32 of Set 8 | malaya vishera
# Processing Record 33 of Set 8 | kloulklubed
# Processing Record 34 of Set 8 | samarai
# Processing Record 35 of Set 8 | caravelas
# Processing Record 36 of Set 8 | santa catalina
# Processing Record 37 of Set 8 | itarema
# Processing Record 38 of Set 8 | tazovskiy
# Processing Record 39 of Set 8 | yeppoon
# Processing Record 40 of Set 8 | bingol
# Processing Record 41 of Set 8 | tshikapa
# Processing Record 42 of Set 8 | mafinga
# City not found. Skipping...
# Processing Record 43 of Set 8 | greenville
# Processing Record 44 of Set 8 | bilibino
# Processing Record 45 of Set 8 | manacor
# Processing Record 46 of Set 8 | bud
# Processing Record 47 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 48 of Set 8 | tromso
# Processing Record 49 of Set 8 | karratha
# Processing Record 50 of Set 8 | mokrous
# Processing Record 1 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 9 | don sak
# Processing Record 3 of Set 9 | salinas
# Processing Record 4 of Set 9 | burica
# City not found. Skipping...
# Processing Record 5 of Set 9 | constantine
# Processing Record 6 of Set 9 | launceston
# Processing Record 7 of Set 9 | dezhou
# Processing Record 8 of Set 9 | nome
# Processing Record 9 of Set 9 | sanpaul
# Processing Record 10 of Set 9 | kidal
# Processing Record 11 of Set 9 | honiara
# Processing Record 12 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 9 | sierra vista
# Processing Record 14 of Set 9 | kulhudhuffushi
# Processing Record 15 of Set 9 | clyde river
# Processing Record 16 of Set 9 | port-cartier
# Processing Record 17 of Set 9 | dibaya
# City not found. Skipping...
# Processing Record 18 of Set 9 | taoudenni
# Processing Record 19 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 9 | inuvik
# Processing Record 21 of Set 9 | cap malheureux
# Processing Record 22 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 23 of Set 9 | mehamn
# Processing Record 24 of Set 9 | luganville
# Processing Record 25 of Set 9 | salem
# Processing Record 26 of Set 9 | nichinan
# Processing Record 27 of Set 9 | tambopata
# City not found. Skipping...
# Processing Record 28 of Set 9 | pochutla
# Processing Record 29 of Set 9 | la libertad
# Processing Record 30 of Set 9 | kangaatsiaq
# Processing Record 31 of Set 9 | roald
# Processing Record 32 of Set 9 | tokmak
# Processing Record 33 of Set 9 | asau
# City not found. Skipping...
# Processing Record 34 of Set 9 | sulurpeta
# City not found. Skipping...
# Processing Record 35 of Set 9 | avarua
# Processing Record 36 of Set 9 | roma
# Processing Record 37 of Set 9 | eyrarbakki
# Processing Record 38 of Set 9 | polson
# Processing Record 39 of Set 9 | jinchengjiang
# City not found. Skipping...
# Processing Record 40 of Set 9 | chifeng
# Processing Record 41 of Set 9 | ambon
# Processing Record 42 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 9 | osorno
# Processing Record 44 of Set 9 | sungairaya
# Processing Record 45 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 46 of Set 9 | houston
# Processing Record 47 of Set 9 | ongole
# Processing Record 48 of Set 9 | makakilo city
# Processing Record 49 of Set 9 | sulya
# Processing Record 50 of Set 9 | nouakchott
# Processing Record 1 of Set 10 | fonte boa
# Processing Record 2 of Set 10 | lavrentiya
# Processing Record 3 of Set 10 | fomboni
# Processing Record 4 of Set 10 | bandarbeyla
# Processing Record 5 of Set 10 | lata
# Processing Record 6 of Set 10 | seremban
# Processing Record 7 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 8 of Set 10 | guicheng
# City not found. Skipping...
# Processing Record 9 of Set 10 | tanout
# Processing Record 10 of Set 10 | kansk
# Processing Record 11 of Set 10 | porto novo
# Processing Record 12 of Set 10 | rocha
# Processing Record 13 of Set 10 | kamenka
# Processing Record 14 of Set 10 | tupik
# Processing Record 15 of Set 10 | otradnoye
# Processing Record 16 of Set 10 | kieta
# Processing Record 17 of Set 10 | komsomolets
# Processing Record 18 of Set 10 | tutoia
# Processing Record 19 of Set 10 | ban dung
# Processing Record 20 of Set 10 | pandharpur
# Processing Record 21 of Set 10 | bereda
# Processing Record 22 of Set 10 | itacoatiara
# Processing Record 23 of Set 10 | yuancheng
# City not found. Skipping...
# Processing Record 24 of Set 10 | wembley
# Processing Record 25 of Set 10 | am timan
# Processing Record 26 of Set 10 | dongying
# Processing Record 27 of Set 10 | dudinka
# Processing Record 28 of Set 10 | hobyo
# Processing Record 29 of Set 10 | acarau
# City not found. Skipping...
# Processing Record 30 of Set 10 | emirdag
# Processing Record 31 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 10 | marang
# City not found. Skipping...
# Processing Record 33 of Set 10 | santa isabel do rio negro
# Processing Record 34 of Set 10 | adrar
# Processing Record 35 of Set 10 | soe
# Processing Record 36 of Set 10 | murmashi
# Processing Record 37 of Set 10 | vestmanna
# Processing Record 38 of Set 10 | camargo
# Processing Record 39 of Set 10 | kupang
# Processing Record 40 of Set 10 | yarmouth
# Processing Record 41 of Set 10 | broome
# Processing Record 42 of Set 10 | goderich
# Processing Record 43 of Set 10 | flinders
# Processing Record 44 of Set 10 | pontal do parana
# Processing Record 45 of Set 10 | ugoofaaru
# Processing Record 46 of Set 10 | boa vista
# Processing Record 47 of Set 10 | peace river
# Processing Record 48 of Set 10 | yumen
# Processing Record 49 of Set 10 | illapel
# Processing Record 50 of Set 10 | ilabaya
# Processing Record 1 of Set 11 | muros
# Processing Record 2 of Set 11 | viedma
# Processing Record 3 of Set 11 | quartucciu
# Processing Record 4 of Set 11 | atar
# Processing Record 5 of Set 11 | chaa-khol
# City not found. Skipping...
# Processing Record 6 of Set 11 | reinosa
# Processing Record 7 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 11 | siderno
# Processing Record 9 of Set 11 | nizhneangarsk
# Processing Record 10 of Set 11 | sobolevo
# Processing Record 11 of Set 11 | san luis
# Processing Record 12 of Set 11 | sao joao do piaui
# Processing Record 13 of Set 11 | vanavara
# Processing Record 14 of Set 11 | mojokerto
# Processing Record 15 of Set 11 | senno
# Processing Record 16 of Set 11 | sile
# Processing Record 17 of Set 11 | turayf
# Processing Record 18 of Set 11 | novita
# Processing Record 19 of Set 11 | coracora
# Processing Record 20 of Set 11 | margate
# Processing Record 21 of Set 11 | tukrah
# City not found. Skipping...
# Processing Record 22 of Set 11 | kyra
# City not found. Skipping...
# Processing Record 23 of Set 11 | mmabatho
# Processing Record 24 of Set 11 | gallup
# Processing Record 25 of Set 11 | loudi
# Processing Record 26 of Set 11 | turinsk
# Processing Record 27 of Set 11 | benguela
# Processing Record 28 of Set 11 | maragua
# Processing Record 29 of Set 11 | eravur
# Processing Record 30 of Set 11 | bar harbor
# Processing Record 31 of Set 11 | riobamba
# Processing Record 32 of Set 11 | dolores
# Processing Record 33 of Set 11 | barcelos
# Processing Record 34 of Set 11 | yarada
# Processing Record 35 of Set 11 | khrenovoye
# Processing Record 36 of Set 11 | alad
# Processing Record 37 of Set 11 | rongcheng
# Processing Record 38 of Set 11 | port lincoln
# Processing Record 39 of Set 11 | naples
# Processing Record 40 of Set 11 | ambovombe
# Processing Record 41 of Set 11 | melekhovskaya
# City not found. Skipping...
# Processing Record 42 of Set 11 | buluang
# Processing Record 43 of Set 11 | igarka
# Processing Record 44 of Set 11 | yemtsa
# Processing Record 45 of Set 11 | ozernovskiy
# Processing Record 46 of Set 11 | mount isa
# Processing Record 47 of Set 11 | reutov
# Processing Record 48 of Set 11 | san rafael
# Processing Record 49 of Set 11 | otane
# Processing Record 50 of Set 11 | alofi
# Processing Record 1 of Set 12 | le port
# Processing Record 2 of Set 12 | ho
# City not found. Skipping...
# Processing Record 3 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 12 | voyinka
# Processing Record 5 of Set 12 | dzhebariki-khaya
# Processing Record 6 of Set 12 | baykit
# Processing Record 7 of Set 12 | aleksandrovskoye
# Processing Record 8 of Set 12 | monduli
# Processing Record 9 of Set 12 | farnham
# Processing Record 10 of Set 12 | tuy hoa
# Processing Record 11 of Set 12 | tripoli
# Processing Record 12 of Set 12 | catuday
# Processing Record 13 of Set 12 | moron
# Processing Record 14 of Set 12 | kosino
# Processing Record 15 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 12 | valparaiso
# Processing Record 17 of Set 12 | calarasi
# Processing Record 18 of Set 12 | namatanai
# Processing Record 19 of Set 12 | maymyo
# Processing Record 20 of Set 12 | lahad datu
# Processing Record 21 of Set 12 | labuhan
# Processing Record 22 of Set 12 | nemuro
# Processing Record 23 of Set 12 | pangai
# Processing Record 24 of Set 12 | ortakoy
# Processing Record 25 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 26 of Set 12 | fare
# Processing Record 27 of Set 12 | kununurra
# Processing Record 28 of Set 12 | dhidhdhoo
# Processing Record 29 of Set 12 | krasnoselkup
# City not found. Skipping...
# Processing Record 30 of Set 12 | sorland
# Processing Record 31 of Set 12 | myitkyina
# Processing Record 32 of Set 12 | muli
# Processing Record 33 of Set 12 | aksarka
# Processing Record 34 of Set 12 | karangampel
# Processing Record 35 of Set 12 | hare bay
# Processing Record 36 of Set 12 | soldotna
# Processing Record 37 of Set 12 | seymchan
# Processing Record 38 of Set 12 | bratsk
# Processing Record 39 of Set 12 | ksenyevka
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City    Lat    Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0             Chuy -33.69 -53.46     60.85        83           3       11.27
# 1  Arraial Do Cabo -22.97 -42.02     77.00        88          75        5.82
# 2          Ushuaia -54.81 -68.31     57.20        47           6       13.87
# 3        Geraldton  49.72 -86.95      1.40        77          20        5.82
# 4           Tiznit  29.70  -9.73     54.25        53          17        1.57
# 5            Sitka  37.17 -99.65     55.00        46         100        9.37
# 6  Aranda De Duero  41.67  -3.69     34.95        91          56        7.76
# 7         Buchanan   5.88 -10.05     78.80        94          75        2.48
# 8      Port Alfred -33.59  26.89     63.00        96         100        5.01
# 9           Albany  42.65 -73.75     44.01        91          90        3.09
#
#   Country      Description  Rain  Snow                 Date
# 0      UY        clear sky  0.00   0.0  2019-11-11 00:19:37
# 1      BR    broken clouds  0.00   0.0  2019-11-11 00:19:57
# 2      AR        clear sky  0.00   0.0  2019-11-11 00:19:14
# 3      CA       few clouds  0.00   0.0  2019-11-11 00:19:35
# 4      MA       few clouds  0.00   0.0  2019-11-11 00:19:59
# 5      US  overcast clouds  0.00   0.0  2019-11-11 00:19:50
# 6      ES    broken clouds  0.00   0.0  2019-11-11 00:21:31
# 7      LR    broken clouds  0.00   0.0  2019-11-11 00:21:31
# 8      ZA       light rain  0.56   0.0  2019-11-11 00:19:28
# 9      US  overcast clouds  0.00   0.0  2019-11-11 00:19:12

# %%
# Create the output file (CSV).
output_data_file = "Weather_data/WeatherPy_Challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
weather_reorder= ['City','Country','Date','Lat','Lng','Max Temp','Humidity', 'Cloudiness','Wind Speed','Description','Rain','Snow']
city_data_df=city_data_df[weather_reorder]
city_data_df.head(15)
# Out:
#                City Country                 Date    Lat     Lng  Max Temp  \
# 0              Chuy      UY  2019-11-11 00:19:37 -33.69  -53.46     60.85
# 1   Arraial Do Cabo      BR  2019-11-11 00:19:57 -22.97  -42.02     77.00
# 2           Ushuaia      AR  2019-11-11 00:19:14 -54.81  -68.31     57.20
# 3         Geraldton      CA  2019-11-11 00:19:35  49.72  -86.95      1.40
# 4            Tiznit      MA  2019-11-11 00:19:59  29.70   -9.73     54.25
# 5             Sitka      US  2019-11-11 00:19:50  37.17  -99.65     55.00
# 6   Aranda De Duero      ES  2019-11-11 00:21:31  41.67   -3.69     34.95
# 7          Buchanan      LR  2019-11-11 00:21:31   5.88  -10.05     78.80
# 8       Port Alfred      ZA  2019-11-11 00:19:28 -33.59   26.89     63.00
# 9            Albany      US  2019-11-11 00:19:12  42.65  -73.75     44.01
# 10        Piacabucu      BR  2019-11-11 00:20:11 -10.41  -36.43     77.09
# 11         Portland      US  2019-11-11 00:21:02  43.66  -70.25     44.60
# 12      Meadow Lake      CA  2019-11-11 00:17:34  54.13 -108.44      3.20
# 13           Kokopo      PG  2019-11-11 00:21:32  -4.34  152.27     82.13
# 14           Narsaq      GL  2019-11-11 00:19:40  60.91  -46.05     33.80
#
#     Humidity  Cloudiness  Wind Speed       Description  Rain  Snow
# 0         83           3       11.27         clear sky  0.00   0.0
# 1         88          75        5.82     broken clouds  0.00   0.0
# 2         47           6       13.87         clear sky  0.00   0.0
# 3         77          20        5.82        few clouds  0.00   0.0
# 4         53          17        1.57        few clouds  0.00   0.0
# 5         46         100        9.37   overcast clouds  0.00   0.0
# 6         91          56        7.76     broken clouds  0.00   0.0
# 7         94          75        2.48     broken clouds  0.00   0.0
# 8         96         100        5.01        light rain  0.56   0.0
# 9         91          90        3.09   overcast clouds  0.00   0.0
# 10        80          42        9.71  scattered clouds  0.00   0.0
# 11        45          90        6.93   overcast clouds  0.00   0.0
# 12        71          75        8.05     broken clouds  0.00   0.0
# 13        79          99       13.18   overcast clouds  0.00   0.0
# 14        80         100       32.21        light snow  0.00   0.0
